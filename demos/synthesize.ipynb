# %%
# %load_ext autoreload
# %autoreload 2
from synthpop.recipes.starter import Starter
from synthpop.synthesizer import synthesize_all, enable_logging 
import os
enable_logging()

# %%
starter = Starter(os.environ["CENSUS"], "CA", "Sonoma County")

# %%
import pandas as pd
ind = pd.Series(["06", "097", "150500", "1"], index=["state", "county", "tract", "block group"])

# %%
hh = synthesize_all(starter, indexes=[ind])
# Out:
# Synthesizing at geog level: 'block_group' (number of geographies is 387)
# Synthesizing geog id:
# state              06
# county            097
# tract          150500
# block group         1
# dtype: object
# Household marginal
# cat_name  cat_value
# cars      none             2
#           one             41
#           two or more     86
# children  no             132
#           yes              0
# income    gt100           44
#           gt35-lt100      48
#           lt35            40
# workers   none            33
#           one             65
#           two or more     31
# Name: (06, 097, 150500, 1), dtype: int64
# Person marginal
# cat_name  cat_value
# age       19 and under     15
#           20 to 35        199
#           35 to 60        265
#           above 60        327
# race      asian            12
#           black            36
#           other            53
#           white           705
# sex       female          417
#           male            389
# ...

# %%
hh.describe()
# Out:
#            Unnamed: 0      serialno  DIVISION  PUMA00  REGION   ADJHSG  \
# count      888.000000  8.880000e+02       888     888     888      888
# mean   1017186.502252  2.012001e+12         9      -9       4  1000000
# std      45369.146229  4.474292e+05         0       0       0        0
# min     940148.000000  2.012000e+12         9      -9       4  1000000
# 25%     973803.750000  2.012000e+12         9      -9       4  1000000
# 50%    1019804.000000  2.012001e+12         9      -9       4  1000000
# 75%    1054023.000000  2.012001e+12         9      -9       4  1000000
# max    1093226.000000  2.012001e+12         9      -9       4  1000000
#
#                ADJINC        WGTP          NP        TYPE         ACR  \
# count      888.000000  888.000000  888.000000  888.000000  711.000000
# mean   1010207.000000   13.777027    2.248874    1.112613    1.250352
# std          0.011871   12.264735    1.475848    0.398332    0.529998
# ...
