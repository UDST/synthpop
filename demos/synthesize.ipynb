# %%
# %load_ext autoreload
# %autoreload 2
from popgen.recipes.starter import Starter
from popgen.synthesizer import SynthPop
import os

# %%
sp = SynthPop(Starter(os.environ["CENSUS"], "CA", "Napa County"))

# %%
sp.synthesize_all(debug=True)
# Out:
# Synthesizing at geog level: 'block_group'
#
# Synthesizing geog id:
# state              06
# county            055
# tract          200201
# block group         1
# dtype: object
#
# Household marginal
# cat_name  cat_value
# cars      none            33
#           one            117
#           two or more    264
# children  no             195
#           yes            221
# income    gt100           46
#           gt35-lt100     159
#           lt35           211
# workers   none           102
#           one            187
#           two or more    126
# Name: (06, 055, 200201, 1), dtype: int64
#
# Person marginal
# cat_name  cat_value
# age       19 and under    247
#           20 to 35        220
#           35 to 60        329
#           above 60        132
# race      asian            13
#           black             0
#           other            89
#           white           826
# sex       female          502
#           male            426
# ...
