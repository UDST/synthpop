# %%
# %load_ext autoreload
# %autoreload 2
from synthpop.recipes.starter import Starter
from synthpop.synthesizer import *
import os

# %%
starter = Starter(os.environ["CENSUS"], "CA", "Napa County")

# %%
hh = synthesize_all(starter, debug=True)
# Out:
# Synthesizing at geog level: 'block_group'
#
# Synthesizing geog id:
# state              06
# county            055
# tract          200201
# block group         1
# dtype: object
#
# Household marginal
# cat_name  cat_value
# cars      none            33
#           one            117
#           two or more    264
# children  no             195
#           yes            221
# income    gt100           46
#           gt35-lt100     159
#           lt35           211
# workers   none           102
#           one            187
#           two or more    126
# Name: (06, 055, 200201, 1), dtype: int64
#
# Person marginal
# cat_name  cat_value
# age       19 and under    247
#           20 to 35        220
#           35 to 60        329
#           above 60        132
# race      asian            13
#           black             0
#           other            89
#           white           826
# sex       female          502
#           male            426
# ...

# %%
hh.describe()
# Out:
#            Unnamed: 0      serialno  DIVISION  PUMA00  REGION   ADJHSG  \
# count      414.000000  4.140000e+02       414     414     414      414
# mean   1011818.432367  2.012001e+12         9      -9       4  1000000
# std      46537.371590  4.534967e+05         0       0       0        0
# min     941126.000000  2.012000e+12         9      -9       4  1000000
# 25%     967752.750000  2.012000e+12         9      -9       4  1000000
# 50%    1011855.500000  2.012001e+12         9      -9       4  1000000
# 75%    1053937.750000  2.012001e+12         9      -9       4  1000000
# max    1093226.000000  2.012001e+12         9      -9       4  1000000
#
#         ADJINC        WGTP          NP        TYPE         ACR        AGS  \
# count      414  414.000000  414.000000  414.000000  341.000000  57.000000
# mean   1010207   13.997585    2.289855    1.101449    1.240469   1.122807
# std          0   12.182928    1.569394    0.398967    0.548478   0.683222
# ...
