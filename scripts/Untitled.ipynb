# %%
import pandas as pd

# %%
pums_relationship_file_url = "https://s3-us-west-2.amazonaws.com/synthpop-data/" + "tract10_to_puma.csv"

pums_relationship_df = \
                pd.read_csv(pums_relationship_file_url, dtype={
                    "statefp": "object",
                    "countyfp": "object",
                    "tractce": "object",
                    "puma10_id": "object",
                    "puma00_id": "object",
                })

# %%
r0 = pums_relationship_df.query("statefp == '06' and countyfp == '037' and tractce == '137000'")

# %%
len(r0)
# Out:
# 0

# %%
r = pums_relationship_df.query("statefp == '06' and countyfp == '037'")

# %%
r["puma10_id"].values[0], r["puma00_id"].values[0]
# Out:
# ('03701', '06101')

# %%
r
# Out:
#      statefp countyfp tractce puma10_id puma00_id
# 4731      06      037  900102     03701     06101
# 4732      06      037  900103     03701     06101
# 4733      06      037  900104     03701     06101
# 4734      06      037  900201     03701     06101
# 4735      06      037  900300     03701     06101
# 4736      06      037  901209     03701     06101
# 4737      06      037  901210     03701     06101
# 4738      06      037  901213     03701     06101
# 4739      06      037  910001     03701     04600
# 4740      06      037  910002     03701     06101
# 4741      06      037  910804     03701     06101
# 4742      06      037  910805     03701     06101
# 4743      06      037  910808     03701     06101
# 4744      06      037  910810     03701     06101
# 4745      06      037  910811     03701     06101
# 4746      06      037  910812     03701     06101
# 4747      06      037  910813     03701     06101
# 4748      06      037  911001     03701     06101
# ...
